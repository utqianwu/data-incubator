# %%
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('adm2014_rv.csv') # Use 2014 data as an example
varlist=pd.read_csv('varlist.csv')

# %%
varlist
# Out:
#     varnumber  varname DataType  Fieldwidth format imputationvar  \
# 0           1   UNITID        N           6   Cont           NaN
# 1       10521  ADMCON1        N           2   Disc           NaN
# 2       10526  ADMCON2        N           2   Disc           NaN
# 3       10531  ADMCON3        N           2   Disc           NaN
# 4       10536  ADMCON4        N           2   Disc           NaN
# 5       10541  ADMCON5        N           2   Disc           NaN
# 6       10546  ADMCON6        N           2   Disc           NaN
# 7       10551  ADMCON7        N           2   Disc           NaN
# 8       10556  ADMCON8        N           2   Disc           NaN
# 9       10559  ADMCON9        N           2   Disc           NaN
# 10      11016   APPLCN        N           6   Cont       XAPPLCN
# 11      10566  APPLCNM        N           6   Cont      XAPPLCNM
# 12      10571  APPLCNW        N           6   Cont      XAPPLCNW
# ...

# %%
a = varlist['varname'].values
a
# Out:
# array(['UNITID', 'ADMCON1', 'ADMCON2', 'ADMCON3', 'ADMCON4', 'ADMCON5',
#        'ADMCON6', 'ADMCON7', 'ADMCON8', 'ADMCON9', 'APPLCN', 'APPLCNM',
#        'APPLCNW', 'ADMSSN', 'ADMSSNM', 'ADMSSNW', 'ENRLT', 'ENRLM',
#        'ENRLW', 'ENRLFT', 'ENRLFTM', 'ENRLFTW', 'ENRLPT', 'ENRLPTM',
#        'ENRLPTW', 'SATNUM', 'SATPCT', 'ACTNUM', 'ACTPCT', 'SATVR25',
#        'SATVR75', 'SATMT25', 'SATMT75', 'SATWR25', 'SATWR75', 'ACTCM25',
#        'ACTCM75', 'ACTEN25', 'ACTEN75', 'ACTMT25', 'ACTMT75', 'ACTWR25',
#        'ACTWR75'], dtype=object)

# %%
df.head()
# Out:
#    UNITID  ADMCON1  ADMCON2  ADMCON3  ADMCON4  ADMCON5  ADMCON6  ADMCON7  \
# 0  100654        1        2        1        2        3        2        1
# 1  100663        1        3        1        1        3        3        1
# 2  100706        1        2        1        1        3        2        1
# 3  100724        1        3        2        3        3        3        1
# 4  100751        1        2        1        1        3        3        1
#
#    ADMCON8  ADMCON9    ...    XACTEN75  ACTEN75 XACTMT25  ACTMT25 XACTMT75  \
# 0        1        3    ...           R     19.0        R     15.0        R
# 1        3        3    ...           R     29.0        R     19.0        R
# 2        1        3    ...           R     31.0        R     23.0        R
# 3        1        3    ...           R     19.0        R     15.0        R
# 4        1        3    ...           R     32.0        R     21.0        R
#
#    ACTMT75 XACTWR25  ACTWR25 XACTWR75  ACTWR75
# ...

# %%
data = df[['APPLCN','ADMSSN', 'ENRLT', 'SATVR25','SATVR75', 'SATMT25', 'SATMT75', 'SATWR25', 'SATWR75']]
data.dropna(inplace=True)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.head()
# Out:
#     APPLCN   ADMSSN   ENRLT  SATVR25  SATVR75  SATMT25  SATMT75  SATWR25  \
# 0     9901   5204.0  1207.0    377.0    470.0    370.0    470.0    370.0
# 4    33736  17221.0  6824.0    490.0    620.0    500.0    630.0    480.0
# 6    16958  14154.0  4592.0    520.0    630.0    530.0    645.0    520.0
# 17    1821   1353.0   540.0    495.0    600.0    460.0    595.0    480.0
# 20    3327   2725.0   730.0    510.0    620.0    500.0    615.0    500.0
#
#     SATWR75
# 0     470.0
# 4     600.0
# 6     610.0
# 17    585.0
# 20    610.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 730 entries, 0 to 2232
# Data columns (total 9 columns):
# APPLCN     730 non-null int64
# ADMSSN     730 non-null float64
# ENRLT      730 non-null float64
# SATVR25    730 non-null float64
# SATVR75    730 non-null float64
# SATMT25    730 non-null float64
# SATMT75    730 non-null float64
# SATWR25    730 non-null float64
# SATWR75    730 non-null float64
# dtypes: float64(8), int64(1)
# memory usage: 57.0 KB

# %%
data.describe()
# Out:
#              APPLCN        ADMSSN         ENRLT     SATVR25     SATVR75  \
# count    730.000000    730.000000    730.000000  730.000000  730.000000
# mean    7464.215068   3805.882192   1096.401370  478.182192  585.438356
# std    11123.196537   4890.885341   1458.373981   75.204547   74.692986
# min        3.000000      3.000000      2.000000  290.000000  400.000000
# 25%     1393.250000    878.750000    262.000000  430.000000  530.000000
# 50%     3281.500000   1952.000000    521.000000  460.000000  580.000000
# 75%     7961.500000   4617.750000   1281.250000  520.000000  630.000000
# max    86537.000000  36088.000000  10835.000000  730.000000  800.000000
#
#           SATMT25     SATMT75     SATWR25     SATWR75
# count  730.000000  730.000000  730.000000  730.000000
# mean   485.864384  593.842466  466.638356  572.223288
# std     81.371370   79.004878   81.332815   79.407620
# min    250.000000  400.000000  280.000000  380.000000
# ...

# %%
data['AMISSION RATE'] = data['ADMSSN']/data['APPLCN']
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sat=data[['AMISSION RATE','SATVR75','SATMT75','SATWR75']]

# %%
sns.distplot(sat['AMISSION RATE'])

# %%
sns.pairplot(sat)
